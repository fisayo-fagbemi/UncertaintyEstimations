# %%
# Crossplot generation using lithologic algorithms [Python Porgramming Language] for Jaba Field, well 1. 
# Modified: 23/10/2021
# Created by: Fisayo Fagbemi

# %%
# Import required python libraries

import pandas as pd
import matplotlib.pyplot as plt
import lasio

# %%
# Import dataset for well 1. Repeat same for all wells

las = lasio.read("Well_A.las")

# %%
# Perform a smart review of dataset

df = las.df()
df.describe()
# Out:
#               RHOB         DT:1         DT:2          LLD           GR
# count  9778.000000  9793.000000  9806.000000  9791.000000  8637.000000
# mean      2.257625   100.908346   104.355664   100.905400    62.192282
# std       0.145989    11.910640   447.387043    11.906195    27.883760
# min       1.656100    56.235400     0.790300    56.254800     4.790300
# 25%       2.156425    92.353600     2.274725    92.354950    38.343800
# 50%       2.241600    99.431700     6.123750    99.431500    59.883100
# 75%       2.364800   108.217300    17.965950   108.218000    87.391700
# max       2.674300   146.176800  4244.920000   146.176000   155.457500

# %%
# Validate Data cleanliness and modify if necessary

las.sections.keys()
# Out:
# dict_keys(['Version', 'Well', 'Curves', 'Parameter', 'Other'])

# %%
las.sections['Version']
# Out:
# [HeaderItem(mnemonic="VERS", unit="", value="2.0", descr="CWLS LOG ASCII STANDA"),
#  HeaderItem(mnemonic="WRAP", unit="", value="NO", descr="ONE LINE PER DEPTH STE")]

# %%
las.sections['Well']
# Out:
# [HeaderItem(mnemonic="STRT", unit="ft", value="5000.0", descr="START DEPTH"),
#  HeaderItem(mnemonic="STEP", unit="ft", value="0.5", descr="STEP DEPTH"),
#  HeaderItem(mnemonic="STOP", unit="ft", value="10020.0", descr="STOP DEPTH"),
#  HeaderItem(mnemonic="NULL", unit="", value="-999.25", descr="NULL VALUE"),
#  HeaderItem(mnemonic="WELL", unit="", value="Well_A", descr="WELL"),
#  HeaderItem(mnemonic="XWELL", unit="m", value="523415", descr="X POS"),
#  HeaderItem(mnemonic="YWELL", unit="m", value="108600", descr="Y POS"),
#  HeaderItem(mnemonic="EDF", unit="", value="58.23", descr="DERICK FLOOR ELEVATI")]

# %%
las.sections['Curves']
# Out:
# [CurveItem(mnemonic="DEPT", unit="ft", value="", descr="DEPTH", original_mnemonic="DEPT", data.shape=(10041,)),
#  CurveItem(mnemonic="RHOB", unit="g/cm3", value="", descr="192", original_mnemonic="RHOB", data.shape=(10041,)),
#  CurveItem(mnemonic="DT:1", unit="us/ft", value="", descr="119", original_mnemonic="DT", data.shape=(10041,)),
#  CurveItem(mnemonic="DT:2", unit="us/ft", value="", descr="104", original_mnemonic="DT", data.shape=(10041,)),
#  CurveItem(mnemonic="LLD", unit="ohm.m", value="", descr="108", original_mnemonic="LLD", data.shape=(10041,)),
#  CurveItem(mnemonic="GR", unit="API", value="", descr="103", original_mnemonic="GR", data.shape=(10041,))]

# %%
for count, curve in enumerate(las.curves):
    print(f"Curve: {curve.mnemonic}, Units: {curve.unit}, Description: {curve.descr}")
print(f"There are a total of: {count+1} curves present within this file")
# Out:
# Curve: DEPT, Units: ft, Description: DEPTH
# Curve: RHOB, Units: g/cm3, Description: 192
# Curve: DT:1, Units: us/ft, Description: 119
# Curve: DT:2, Units: us/ft, Description: 104
# Curve: LLD, Units: ohm.m, Description: 108
# Curve: GR, Units: API, Description: 103
# There are a total of: 6 curves present within this file

# %%
for item in las.curves:
    print(f"{item.descr} ({item.mnemonic}): {item.value}")
# Out:
# DEPTH (DEPT):
# 192 (RHOB):
# 119 (DT:1):
# 104 (DT:2):
# 108 (LLD):
# 103 (GR):

# %%
las.sections['Other']
# Out:
# ''

# %%
df.head(240)
# Out:
#           RHOB      DT:1     DT:2      LLD  GR
# DEPT
# 5000.0     NaN       NaN      NaN      NaN NaN
# 5000.5     NaN       NaN      NaN      NaN NaN
# 5001.0     NaN       NaN      NaN      NaN NaN
# 5001.5     NaN       NaN      NaN      NaN NaN
# 5002.0     NaN       NaN      NaN      NaN NaN
# ...        ...       ...      ...      ...  ..
# 5117.5  2.1477  107.9340  24.6210  107.934 NaN
# 5118.0  2.1206  107.9340  24.6211  107.933 NaN
# 5118.5  2.0900  110.2834  24.3661  110.282 NaN
# 5119.0  2.0708  112.1832  24.0550  112.184 NaN
# 5119.5  2.0615  118.5570  23.4867  118.550 NaN
#
# [240 rows x 5 columns]

# %%
well = las.df()

# %%
well.head()
# Out:
#         RHOB  DT:1  DT:2  LLD  GR
# DEPT
# 5000.0   NaN   NaN   NaN  NaN NaN
# 5000.5   NaN   NaN   NaN  NaN NaN
# 5001.0   NaN   NaN   NaN  NaN NaN
# 5001.5   NaN   NaN   NaN  NaN NaN
# 5002.0   NaN   NaN   NaN  NaN NaN

# %%
well.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 10041 entries, 5000.0 to 10020.0
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RHOB    9778 non-null   float64
#  1   DT:1    9793 non-null   float64
#  2   DT:2    9806 non-null   float64
#  3   LLD     9791 non-null   float64
#  4   GR      8637 non-null   float64
# dtypes: float64(5)
# memory usage: 470.7 KB

# %%
well.plot()
# Out:
# <AxesSubplot:xlabel='DEPT'>

# %%
well.plot(y='GR')
# Out:
# <AxesSubplot:xlabel='DEPT'>

# %%
well.plot(y='LLD')
# Out:
# <AxesSubplot:xlabel='DEPT'>

# %%
well.plot(y='DT:1')
# Out:
# <AxesSubplot:xlabel='DEPT'>

# %%
well.plot(y='DT:2')
# Out:
# <AxesSubplot:xlabel='DEPT'>

# %%
well.plot(y='RHOB')
# Out:
# <AxesSubplot:xlabel='DEPT'>

# %%
plt.scatter(x = 'GR', y = 'RHOB', data = df)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (8, 8)

# %%
# Perform, modify plots and apply notations

plt.style.use('bmh')

plt.scatter(x = 'GR', y = 'RHOB', data = df, c ='DT:2', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0, 140)

#plt.ylim(16, 28)

plt.yscale('log')
plt.semilogy();

plt.ylabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.xlabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Sonic - us/ft')

plt.show()

# %%
plt.style.use('bmh')

plt.scatter(x = 'GR', y = 'LLD', data = df, c ='DT:2', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0, 140)

#plt.ylim(16, 28)

plt.yscale('log')
#plt.semilogy();

plt.ylabel('Resistivity (LLD) - ohm.m', fontsize=14)

plt.xlabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Sonic - us/ft')

plt.show()
